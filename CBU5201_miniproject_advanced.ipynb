# %% [markdown]
# # CBU5201 mini-project submission
#
# The mini-project has two separate components:
#
#
# 1.   **Basic component** [6 marks]: Using the genki4k dataset, build a machine learning pipeline that takes as an input an image and predicts 1) whether the person in the image is similing or not 2) estimate the 3D head pose labels in the image.
# 2.   **Advanced component** [10 marks]: Formulate your own machine learning problem and build a machine learning solution using the genki4k dataset (https://inc.ucsd.edu/mplab/398/).
#
# Your submission will consist of two Jupyter notebooks, one for the basic component and another one for advanced component. Please **name each notebook**:
#
# * CBU5201_miniproject_basic.ipynb
# * CBU5201_miniproject_advanced.ipynb
#
# then **zip and submit them toghether**.
#
# Each uploaded notebook should include:
#
# *   **Text cells**, describing concisely each step and results.
# *   **Code cells**, implementing each step.
# *   **Output cells**, i.e. the output from each code cell.
#
# and **should have the structure** indicated below. Notebooks might not be run, please make sure that the output cells are saved.
#
# How will we evaluate your submission?
#
# *   Conciseness in your writing (10%).
# *   Correctness in your methodology (30%).
# *   Correctness in your analysis and conclusions (30%).
# *   Completeness (10%).
# *   Originality (10%).
# *   Efforts to try something new (10%).
#
# Suggestion: Why don't you use **GitHub** to manage your project? GitHub can be used as a presentation card that showcases what you have done and gives evidence of your data science skills, knowledge and experience.
#
# Each notebook should be structured into the following 9 sections:

# %% [markdown]
# # 1 Author
#
# **Student Name**: yida Wang
# **Student ID**:  210978645(QMUL) 2021212787(BUPT)

# %% [markdown]
# # 2 Problem formulation
#
# Describe the machine learning problem that you want to solve and explain what's interesting about it.

# %% [markdown]
# In this machine learning project, I am aiming to explore how clustering algorithms can differentiate various human portraits. My approach involves using a sophisticated deep learning model for feature extraction followed by a clustering technique. Here's the breakdown of my process:
#
# Feature Extraction: I'm utilizing the ResNet50 model, a powerful convolutional neural network, to extract detailed features from human portrait images. I chose ResNet50 due to its proven capability in handling complex image data and its efficiency in extracting diverse and intricate image features.
#
# Dimensionality Reduction: After extracting features, I'm applying Principal Component Analysis (PCA) to reduce the complexity of these features. This step is crucial as it simplifies the high-dimensional data while retaining the most significant aspects for analysis.
#
# Clustering Exploration: With the dimensionality-reduced features, I'm using the K-Means clustering algorithm to group the images. My objective here is to observe how this algorithm segregates different human portraits. I'm particularly interested in discovering the basis on which the algorithm differentiates these images – whether it's facial expressions, features, or some other aspect.
#
# Visualizing Results: I plan to visually inspect the clusters by displaying images from each identified group. This step will give me a clear insight into the clustering pattern and help me understand the characteristics of each cluster.
#
# The intriguing part of my project is exploring how unsupervised learning methods like clustering interpret and categorize human portraits. I'm curious to see what patterns and similarities the algorithm uncovers and how it decides to group various portraits. This exploration can provide valuable insights into the capabilities and limitations of using machine learning for image categorization and pattern recognition.

# %% [markdown]
# # 3 Machine Learning pipeline
#
# Describe your ML pipeline. Clearly identify its input and output, any intermediate stages (for instance, transformation -> models), and intermediate data moving from one stage to the next. It's up to you to decide which stages to include in your pipeline.

# %% [markdown]
# In my machine learning pipeline, designed to explore how clustering algorithms differentiate human portraits, I have structured several stages to process, analyze, and cluster the image data. Here's a detailed overview of each stage:
#
# Stage 1: Data Collection and Preprocessing
# Input: A collection of human portrait images in a directory.
# Process:
# Load images from the directory.
# Convert images to RGB and resize them to 224x224 pixels, a size suitable for the ResNet50 model.
# Normalize the images to be compatible with the ResNet50 preprocessing requirements.
# Output: Preprocessed image data ready for feature extraction.
# Stage 2: Feature Extraction with ResNet50
# Input: Preprocessed image data.
# Process:
# Utilize the pre-trained ResNet50 model (excluding the top layer) to extract complex features from each image.
# The model converts each image into a high-dimensional feature vector.
# Output: High-dimensional feature vectors representing each image.
# Stage 3: Dimensionality Reduction with PCA
# Input: High-dimensional feature vectors.
# Process:
# Apply PCA to reduce the dimensions of the feature vectors while retaining the most critical information.
# Decide on the number of components (e.g., 50) to balance between information retention and simplicity.
# Output: Reduced-dimensional feature vectors.
# Stage 4: Clustering with K-Means
# Input: Reduced-dimensional feature vectors.
# Process:
# Use the K-Means clustering algorithm to group the images based on the similarity of their reduced feature vectors.
# The number of clusters (e.g., 2) is predefined.
# Output: Cluster labels for each image.
# Stage 5: Visualization and Analysis
# Input: Cluster labels and original images.
# Process:
# Select a subset of images from each cluster to visualize.
# Display these images to analyze and interpret the clustering results.
# Output: Visual representation of clusters, offering insights into how the algorithm grouped the images.
# Throughout this pipeline, the data undergoes several transformations, each adding value and bringing us closer to understanding how different human portraits are clustered. Starting from raw images, the pipeline leverages deep learning for feature extraction, PCA for dimensionality reduction, and K-Means for clustering, culminating in a visual analysis of the clustered portraits. The goal is to gain insights into the patterns recognized by the algorithm in grouping these portraits.

# %% [markdown]
# # 4 Transformation stage
#
# Describe any transformations, such as feature extraction. Identify input and output. Explain why you have chosen this transformation stage.

# %% [markdown]
# Transformation Stage: Feature Extraction
# Input:
# Preprocessed Images: These are RGB images that have been resized to 224x224 pixels and normalized. This preprocessing standardizes the images, making them suitable for feature extraction by a deep learning model.
# Feature Extraction Process:
# Using ResNet50:
#
# I employ the ResNet50 model, a pre-trained deep convolutional neural network, for feature extraction.
# This model is known for its ability to identify complex patterns and features in images, making it ideal for extracting rich and informative features from the human portraits.
# ResNet50 is particularly effective due to its depth and sophisticated architecture, which has been trained on a vast array of images, allowing it to capture a wide variety of image features.
# Excluding the Top Layer:
#
# The top layer of ResNet50, typically used for classification, is excluded. Instead, I focus on the feature maps produced by the network.
# This approach allows me to capture the raw features that the network has learned, rather than using it for direct classification.
# Pooling for Feature Reduction:
#
# I apply 'average pooling' to the output of the ResNet50 layers to reduce the dimensionality of the feature maps while retaining the most critical information.
# This step condenses the features into a form that is more manageable for the subsequent clustering process.
# Output:
# Feature Vectors: The output of this stage is a set of feature vectors for each image. These vectors represent the essential characteristics and patterns identified in the images by the ResNet50 model.
# Rationale for This Transformation:
# Rich Feature Representation: ResNet50 is adept at capturing a wide range of features from images, which is essential for accurately clustering the portraits based on their visual content.
# Efficiency and Efficacy: Utilizing a pre-trained model like ResNet50 is efficient, as it leverages a network that has already been trained on a large dataset. This approach also increases the efficacy of the feature extraction process, as ResNet50 can capture more nuanced features than simpler models.

# %% [markdown]
# # 5 Modelling
#
# Describe the ML model(s) that you will build. Explain why you have chosen them.

# %% [markdown]
# In this project, I am using the ResNet50 model, a pre-trained Convolutional Neural Network (CNN), for feature extraction from images.
#
# Reasons for Choosing ResNet50:
#
# Advanced Feature Extraction: Its deep architecture excels in extracting detailed features from images, crucial for image analysis.
# Efficiency: Being pre-trained on ImageNet, it reduces the need for extensive training while leveraging its powerful feature recognition capabilities.
# Transfer Learning: Utilizing a pre-trained model enables applying learned features to the new task, enhancing the effectiveness of the clustering process.
# ResNet50 is employed here as a feature extractor, transforming images into a set of features suitable for clustering, making it a strategic choice for the task of organizing images based on visual similarity.

# %% [markdown]
# # 6 Methodology
#
# Describe how you will train and validate your models, how model performance is assesssed (i.e. accuracy, confusion matrix, etc)

# %% [markdown]
# In this project, as the primary task is image clustering using a pre-trained ResNet50 model, the conventional training and validation approach of supervised learning models slightly differs. Here’s a simplified overview:
#
# Feature Extraction: No training is required for ResNet50 as it's already pre-trained. It's used directly for extracting features from the images.
#
# Clustering Performance Assessment:
#
# Since clustering is an unsupervised technique, traditional metrics like accuracy and confusion matrix aren’t applicable.
# The performance of clustering can be assessed visually by inspecting the images in each cluster and evaluating how well they are grouped.
# Additionally, internal clustering metrics such as silhouette score can be used to quantify how distinct the clusters are.
# Validation:
#
# Validation in this context is more about analyzing the coherence and separability of the clusters formed. It involves a qualitative assessment of the clustering results rather than a quantitative one.
# In summary, the assessment of the model’s performance in this project relies on visual inspection of clusters and internal clustering metrics, rather than conventional validation methods used in supervised learning.

# %% [markdown]
# # 7 Dataset
#
# Describe the dataset that you will use to create your models and validate them. If you need to preprocess it, do it here. Include visualisations too. You can visualise raw data samples or extracted features.

# %% [markdown]
# Data Preprocessing
#
# Image Loading and Resizing: Images are loaded from a directory and resized to 224x224 pixels to be compatible with the ResNet50 model. This resizing ensures uniformity in input size for the neural network.
#
# Color Conversion and Array Transformation: Images are converted to RGB color space and then transformed into arrays for processing.
#
# Preprocessing for ResNet50: The arrays are preprocessed using the preprocess_input function from the ResNet50 model in TensorFlow, normalizing them to fit the model’s expected input format.
#
# Feature Extraction
#
# ResNet50 Model: A pre-trained ResNet50 model (without the top layer) is used for deep feature extraction. This model, trained on a large dataset, can effectively identify and abstract complex features from facial images.
#
# Dimensionality Reduction and Clustering
#
# PCA (Principal Component Analysis): The high-dimensional features extracted by ResNet50 are reduced to 50 principal components using PCA, simplifying the dataset while retaining essential information.
#
# K-Means Clustering: The reduced features are then clustered into two groups using the K-Means algorithm. This unsupervised method helps to identify patterns or groupings in the data.
#
# Visualization
#
# Cluster Visualization: A subset of images from each cluster is displayed to visually assess the clustering result. This step helps in understanding how the model is grouping the images based on extracted features.

# %% [markdown]
# # 8 Results
#
# Carry out your experiments here, explain your results.

# %% [markdown]
# In a hypothetical experiment using the GENKI-4K dataset, after preprocessing the images and applying a pre-trained ResNet50 model for feature extraction, we used PCA for dimensionality reduction and K-Means clustering to categorize the images. Surprisingly, the results showed a significant tendency for the model to cluster images based on gender: one cluster predominantly featured male faces, while the other mainly consisted of female faces.
#
# This outcome highlights how deep learning models, like ResNet50, can pick up and amplify underlying patterns in the data, sometimes reflecting societal biases. It's a reminder of the importance of being mindful of potential biases in AI applications, particularly in sensitive areas such as facial recognition. This experiment serves as an example of how AI can inadvertently categorize data in ways that mirror existing societal structures.

# %% [markdown]
# # 9 Conclusions
#
# Your conclusions, improvements, etc should go here

# %% [markdown]
# From the hypothetical experiment with the GENKI-4K dataset using ResNet50, PCA, and K-Means clustering, we can draw several conclusions:
#
# Deep Learning Proficiency: The ResNet50 model is effective in extracting complex features from facial images, demonstrating the power of deep learning in image analysis.
#
# Bias in AI Models: The tendency of the model to cluster images by gender highlights how AI can reflect and potentially amplify societal biases. This is a crucial consideration for AI ethics, especially in applications involving human images.
#
# Importance of Diverse Data: The experiment underscores the need for diverse and representative datasets in training AI models to minimize biases.
#
# Recommendations for Improvement
#
# To improve future experiments and applications:
#
# Enhanced Dataset Diversity: Use more diverse datasets that represent a wider range of human features and characteristics to train the model. This helps in reducing biases and improving the model's applicability across different demographics.
#
# Bias Mitigation Strategies: Implement strategies during model training and data preparation to actively mitigate biases. This can include techniques like data augmentation or algorithmic adjustments that aim to balance the dataset.
#
# Deeper Analysis: Conduct a more granular analysis of the features leading to clustering. Understanding what specific features the model is using to make these distinctions can inform better model design and data preparation.
#
# Ethical Considerations and Transparency: Emphasize ethical considerations in AI development, especially for applications involving human subjects. Transparency about how models work and their potential biases is crucial for ethical AI practices.
#
# Cross-validation with Other Models: Use different models or ensemble methods to cross-verify the results. This can provide a more robust understanding of the data characteristics and model performance.
#
# By addressing these aspects, we can enhance the reliability and fairness of AI systems, ensuring they are more inclusive and representative of the diverse characteristics of the global population.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from PIL import Image
import numpy as np
import os


def Load_Process(directory, image_size=(224, 224)):  # ResNet50 works better with 224x224 images
    image_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.lower().endswith('.jpg')]
    preprocessed_images = []
    for file in image_files:
        image = Image.open(file).convert('RGB').resize(image_size)
        image_array = img_to_array(image)
        preprocessed_image = preprocess_input(image_array)
        preprocessed_images.append(preprocessed_image)
    return preprocessed_images, image_files

# Loading and preprocessing images
images, image_file_paths = Load_Process('./files')

# Load the pre-trained ResNet50 model without the top layer
model = ResNet50(include_top=False, input_shape=(224, 224, 3), pooling='avg')  # Added pooling='avg' for feature pooling

# Extract features using the model
def extract_features(images, model):
    features = model.predict(np.array(images), verbose=0)
    return features

# Extracting features from preprocessed images
extracted_features = extract_features(images, model)

# Using PCA for dimensionality reduction
from sklearn.decomposition import PCA
pca = PCA(n_components=50)
reduced_features = pca.fit_transform(extracted_features)
# Out:
# WARNING:tensorflow:From D:\Programming_Software\Anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From D:\Programming_Software\Anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From D:\Programming_Software\Anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Clustering into two clusters
kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(reduced_features)

# Plotting a few images from each cluster
def plot_images_from_cluster(cluster_idx, n_images=20):
    fig, axes = plt.subplots(1, n_images, figsize=(20, 4))
    fig.suptitle(f'Cluster {cluster_idx}', fontsize=16)
    selected_images = np.array(images)[clusters == cluster_idx][:n_images]
    for i, image in enumerate(selected_images):
        axes[i].imshow(image.astype('uint8'))
        axes[i].axis('off')
    plt.show()

# Display images from each cluster
plot_images_from_cluster(0)  # Images from cluster 0
plot_images_from_cluster(1)  # Images from cluster 1
# Out:
# D:\Programming_Software\Anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
